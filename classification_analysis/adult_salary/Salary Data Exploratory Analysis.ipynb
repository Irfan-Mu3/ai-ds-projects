# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# In this notebook, we attempt to study a classification problem by hand, and through automation (machine learning).
# The data use for this problem is the salary classification problem - to see if we can classify whether individuals earn (<=50k, >50k) based on attributes such as: Occupation, Education, Age, Capital-gain, etc.. Summarily, we find that we attempt a manual-based decision tree approach to solving the problem.
#
# Whilst the *covariance/correlation* of two random variables is useful to determine whether variables have a funtional relationship, we present the *polarity/polarization* of two random variables as a measure of their seperation with respect to some class attribute - i.e. how far apart are points of a partiular class away from points of another class in Euclidean space. Unfortunately for this problem, neither metrics proved useful.
#
# The dataset for this problem is obtainable from the UCI Machine Learning Repository (https://archive.ics.uci.edu/ml/datasets/Adult).
#
# Note, whilst we have plotted the graphs inline, they are quite unsatisfactory. Therefore we advice changing the plots to be window-based allowing full-screening and zooming in. To do this, in the import section below, change '**%matplotlib notebook'** to '**%matplotlib tk'**', and you will probably need to restart the kernel aswell. **Note that the dataset needed is not included (due to the file size being too large) and you will have to download the dataset using the link above as well to run this.**

# %% [markdown]
# ## Preliminaries (Imports and function definitions)

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import seaborn as sns

# for jupyter:
import sys
sys.path.append('..')

from classification_funcs.classification_plots import create_dummy_matrix, create_classification_plots, create_andrews_plot, \
    create_rel_polarity_matrix, create_quantitative_mekko_charts, create_qualitative_mekko_charts

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:65% !important; }</style>"))

# %matplotlib notebook
# Out:
# <style>.container { width:65% !important; }</style>

# %%
def data_preparation(datafile):
    df = pd.read_csv(datafile)

    # step: remove rows that have unknowns (cells with '?')
    unknown_mask = (df.T != '?').all()
    df = df[unknown_mask]

    return df

# %% [markdown]
# ## Start of Analysis

# %%
df = data_preparation('adult.csv')

df_qual = df.select_dtypes(exclude=np.number)
df_quant = df.select_dtypes(include=np.number)

# For EDA, we not need to remove the last dummy category, but should this be an issue if we do?
df_dummies = create_dummy_matrix(df_qual) 

# change 'Salary' to dummy variable (less than 50K).
y_variable = pd.get_dummies(df['Salary'], prefix='Salary', prefix_sep=': ')['Salary: <=50K']

# %% [markdown]
# ### Andrew curves

# %% [markdown]
# Andrew curves can be used as a quick way to find discriminants.

# %%
# use all variables (with categoricals translated to dummies)
create_andrews_plot(df_dummies,y_variable,num_samples=2000)
# Out:
# <img src="data:image/png;base64,..." width="1162.45">

# %%
# use just the quantitative variables
create_andrews_plot(df_quant,y_variable,num_samples=2000)
# Out:
# <img src="data:image/png;base64,..." width="1163.5666666666666">

# %% [markdown]
# The curves above do not unfortunately show a way to discriminate between the two classes (with class 1 being <=50k and class 0 being >50k). Therefore we will have to press further. Note that the plots are sensitive to the order of the variables. However based on the few different orderings we have tried, we were not able to find any that yielded a difference between the plots of each class.

# %% [markdown]
# ## Exploring the quantitative variables alone

# %% [markdown]
# ### R^2 values and polarity values

# %% [markdown]
# The correlation between a dummy (dichotomous variable - in this case the response variable y) and a quantitative variable may help us in classification. Let us determine the R^2 values (or coefficient of determination [in the case of bivariate regression]).

# %%
df_quant_r2 = (pd.concat([df_quant, y_variable], axis=1).corr() ** 2).sort_values(by=['Salary: <=50K'],
                                                                                      ascending='True')
df_quant_r2['Salary: <=50K']
# Out:
# Fnlwgt            0.000080
# Capital-loss      0.022516
# Capital-gain      0.048928
# Hours-per-week    0.052661
# Age               0.058563
# Education-num     0.112417
# Salary: <=50K     1.000000
# Name: Salary: <=50K, dtype: float64

# %% [markdown]
# There appears to be no strong correlation between the quantative variables and *Salary*. Let us study the the relative polarity next:

# %%
# substep: see if polarity exists between quant. variables
rel_polarity_matrix = create_rel_polarity_matrix(df_quant, y_variable, classes=[1, 0])
rel_polarity_matrix
# Out:
#                      Age    Fnlwgt  Education-num  Capital-gain  Capital-loss  \
# Age             0.273738  0.000437       0.279894      0.121386      0.080993
# Fnlwgt          0.000437  0.000437       0.000437      0.001727      0.000439
# Education-num   0.279894  0.000437       0.406135      0.121385      0.080849
# Capital-gain    0.121386  0.001727       0.121385      0.121385      0.121302
# Capital-loss    0.080993  0.000439       0.080849      0.121302      0.080837
# Hours-per-week  0.257479  0.000437       0.247548      0.121386      0.080946
#
#                 Hours-per-week
# Age                   0.257479
# Fnlwgt                0.000437
# Education-num         0.247548
# Capital-gain          0.121386
# Capital-loss          0.080946
# Hours-per-week        0.238539

# %% [markdown]
# The values of the matrix above indicates that there does not exist much polarity except between Education-num and itself. We can try to see if this is true via the scatterplots below.

# %% [markdown]
# ### 2D scatterplots

# %%
create_classification_plots(df_quant.copy(), y_variable, jitter=True, num_samples=4000, jitter_size=0.05,hide_legend=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1161.3333333333333">

# %% [markdown]
# In the diagram above, the blue dots represent samples of individuals where the salary was (> 50k), and the green are for (<= 50k). The two crosses represent the means, with orange being for (> 50k), and red for (<= 50k).
#
# Note firstly that the images can be misleading since we have chosen to plot only 4000 samples per class. This is not entirely appropriate since there are roughly 22000 rows for the (<= 50k) class whilst there are around 7500 rows for the >50k class. Perhaps a better way to plot the results would be to use scatterplots with a hexagonal binning scheme (see for example [Graphical Techniques for Multivariate Data by Brian Everitt, or Exploratory Data Analysis with MATLAB by Martinez et al.]). Nevertheless, what is consistent is that Capital-gain displays some outliers that are strictly for the class )> 50k).
#
# We see that the rel. polarity values corresponds somewhat to a measure of seperation. Although, the rel. polarity values are rather small.

# %% [markdown]
# ## Exploring qualitative relationships

# %% [markdown]
# ### R^2 and polarity values

# %% [markdown]
# Let us investigate if the qualitative variables can highlight anything for us. We will use the dummy representation of our qualitative variables and study its correlation and relative polarity.

# %%
df_dummies_r2 = (df_dummies.corr() ** 2).sort_values(by=['Salary: <=50K'], ascending='True')
pd.set_option('display.max_rows', len(df_dummies_r2))
print(df_dummies_r2['Salary: <=50K'][-10:])
# Out:
# Education: Bachelors                  0.031986
# Occupation: Prof-specialty            0.032927
# Relationship: Not-in-family           0.037349
# Occupation: Exec-managerial           0.045557
# Sex: Female                           0.046958
# Relationship: Own-child               0.051160
# Marital-status: Never-married         0.102434
# Relationship: Husband                 0.160991
# Marital-status: Married-civ-spouse    0.198397
# Salary: <=50K                         1.000000
# Name: Salary: <=50K, dtype: float64

# %%
# substep: study polarity of qual. variables
rel_polarity_matrix = create_rel_polarity_matrix(df_dummies.drop(columns=['Salary: <=50K']), y_variable, classes=[1, 0])
rel_polarity_matrix
# Out:
#                                             Workclass: Federal-gov  \
# Workclass: Federal-gov                                    0.014786
# Workclass: Local-gov                                      0.007849
# Workclass: Private                                        0.058142
# Workclass: Self-emp-inc                                   0.046358
# Workclass: Self-emp-not-inc                               0.006911
# Workclass: State-gov                                      0.007129
# Education: 10th                                           0.021023
# Education: 11th                                           0.029208
# Education: 12th                                           0.014567
# Education: 1st-4th                                        0.014232
# Education: 5th-6th                                        0.015009
# Education: 7th-8th                                        0.017428
# Education: 9th                                            0.016459
# Education: Assoc-acdm                                     0.007790
# Education: Assoc-voc                                      0.006954
# Education: Bachelors                                      0.111991
# Education: Doctorate                                      0.028470
# Education: HS-grad                                        0.086528
# Education: Masters                                        0.077834
# Education: Preschool                                      0.014495
# Education: Prof-school                                    0.042481
# Marital-status: Divorced                                  0.081062
# Marital-status: Married-AF-spouse                         0.014442
# Marital-status: Married-civ-spouse                        0.557021
# Marital-status: Married-spouse-absent                     0.014266
# Marital-status: Never-married                             0.392987
# Marital-status: Separated                                 0.023697
# Occupation: Adm-clerical                                  0.047077
# Occupation: Armed-Forces                                  0.014688
# Occupation: Craft-repair                                  0.005495
# Occupation: Exec-managerial                               0.141848
# Occupation: Farming-fishing                               0.017137
# Occupation: Handlers-cleaners                             0.036404
# Occupation: Machine-op-inspct                             0.027143
# Occupation: Other-service                                 0.123827
# Occupation: Priv-house-serv                               0.014533
# Occupation: Prof-specialty                                0.108945
# Occupation: Protective-serv                               0.010333
# Occupation: Sales                                         0.005045
# Occupation: Tech-support                                  0.009103
# Relationship: Husband                                     0.473681
# Relationship: Not-in-family                               0.168629
# Relationship: Other-relative                              0.028192
# Relationship: Own-child                                   0.228927
# Relationship: Unmarried                                   0.096108
# Race: Amer-Indian-Eskimo                                  0.013150
# Race: Asian-Pac-Islander                                  0.008394
# Race: Black                                               0.036625
# Race: Other                                               0.013664
# Sex: Female                                               0.204059
# Native-country: Cambodia                                  0.014507
# Native-country: Canada                                    0.013396
# Native-country: China                                     0.013877
# Native-country: Columbia                                  0.014381
# Native-country: Cuba                                      0.013608
# Native-country: Dominican-Republic                        0.014349
# Native-country: Ecuador                                   0.014482
# Native-country: El-Salvador                               0.013995
# Native-country: England                                   0.013632
# Native-country: France                                    0.014361
# Native-country: Germany                                   0.013175
# Native-country: Greece                                    0.014390
# Native-country: Guatemala                                 0.014321
# Native-country: Haiti                                     0.014382
# Native-country: Holand-Netherlands                        0.014777
# Native-country: Honduras                                  0.014664
# Native-country: Hong                                      0.014511
# Native-country: Hungary                                   0.014616
# Native-country: India                                     0.013497
# Native-country: Iran                                      0.014158
# Native-country: Ireland                                   0.014485
# Native-country: Italy                                     0.013846
# Native-country: Jamaica                                   0.014014
# Native-country: Japan                                     0.013948
# Native-country: Laos                                      0.014602
# Native-country: Mexico                                    0.019122
# Native-country: Nicaragua                                 0.014491
# Native-country: Outlying-US(Guam-USVI-etc)                0.014671
# Native-country: Peru                                      0.014510
# Native-country: Philippines                               0.012576
# Native-country: Poland                                    0.014119
# Native-country: Portugal                                  0.014432
# Native-country: Puerto-Rico                               0.013858
# Native-country: Scotland                                  0.014652
# Native-country: South                                     0.013953
# Native-country: Taiwan                                    0.014155
# Native-country: Thailand                                  0.014582
# Native-country: Trinadad&Tobago                           0.014595
# Native-country: United-States                             0.011019
# Native-country: Vietnam                                   0.014245
#
#                                             Workclass: Local-gov  \
# Workclass: Federal-gov                                  0.007849
# Workclass: Local-gov                                    0.004149
# Workclass: Private                                      0.050805
# Workclass: Self-emp-inc                                 0.031831
# Workclass: Self-emp-not-inc                             0.003712
# Workclass: State-gov                                    0.002757
# Education: 10th                                         0.010661
# Education: 11th                                         0.016671
# Education: 12th                                         0.005344
# Education: 1st-4th                                      0.004379
# Education: 5th-6th                                      0.005266
# Education: 7th-8th                                      0.007583
# Education: 9th                                          0.006665
# Education: Assoc-acdm                                   0.002810
# Education: Assoc-voc                                    0.002654
# Education: Bachelors                                    0.096783
# Education: Doctorate                                    0.015500
# Education: HS-grad                                      0.076221
# Education: Masters                                      0.059113
# Education: Preschool                                    0.004146
# Education: Prof-school                                  0.026304
# Marital-status: Divorced                                0.065122
# Marital-status: Married-AF-spouse                       0.004104
# Marital-status: Married-civ-spouse                      0.521817
# Marital-status: Married-spouse-absent                   0.005157
# Marital-status: Never-married                           0.355485
# Marital-status: Separated                               0.012748
# Occupation: Adm-clerical                                0.036564
# Occupation: Armed-Forces                                0.004135
# Occupation: Craft-repair                                0.003133
# Occupation: Exec-managerial                             0.121511
# Occupation: Farming-fishing                             0.008717
# Occupation: Handlers-cleaners                           0.022596
# Occupation: Machine-op-inspct                           0.017928
# Occupation: Other-service                               0.095904
# Occupation: Priv-house-serv                             0.004491
# Occupation: Prof-specialty                              0.092458
# Occupation: Protective-serv                             0.003950
# Occupation: Sales                                       0.002691
# Occupation: Tech-support                                0.003655
# Relationship: Husband                                   0.441567
# Relationship: Not-in-family                             0.147221
# Relationship: Other-relative                            0.015381
# Relationship: Own-child                                 0.188429
# Relationship: Unmarried                                 0.074151
# Race: Amer-Indian-Eskimo                                0.004297
# Race: Asian-Pac-Islander                                0.003083
# Race: Black                                             0.026745
# Race: Other                                             0.004378
# Sex: Female                                             0.182032
# Native-country: Cambodia                                0.004109
# Native-country: Canada                                  0.003958
# Native-country: China                                   0.004012
# Native-country: Columbia                                0.004134
# Native-country: Cuba                                    0.003967
# Native-country: Dominican-Republic                      0.004153
# Native-country: Ecuador                                 0.004105
# Native-country: El-Salvador                             0.004108
# Native-country: England                                 0.003993
# Native-country: France                                  0.004093
# Native-country: Germany                                 0.003940
# Native-country: Greece                                  0.004089
# Native-country: Guatemala                               0.004130
# Native-country: Haiti                                   0.004101
# Native-country: Holand-Netherlands                      0.004148
# Native-country: Honduras                                0.004132
# Native-country: Hong                                    0.004108
# Native-country: Hungary                                 0.004123
# Native-country: India                                   0.004019
# Native-country: Iran                                    0.004071
# Native-country: Ireland                                 0.004104
# Native-country: Italy                                   0.004020
# Native-country: Jamaica                                 0.004062
# Native-country: Japan                                   0.004042
# Native-country: Laos                                    0.004123
# Native-country: Mexico                                  0.008765
# Native-country: Nicaragua                               0.004117
# Native-country: Outlying-US(Guam-USVI-etc)              0.004136
# Marital-status: Married-civ-spouse                 0.588997
# Marital-status: Married-spouse-absent              0.013027
# Marital-status: Never-married                      0.428774
# Marital-status: Separated                          0.030463
# Occupation: Adm-clerical                           0.054946
# Occupation: Armed-Forces                           0.013413
# Occupation: Craft-repair                           0.003405
# Occupation: Exec-managerial                        0.161060
# Occupation: Farming-fishing                        0.018578
# Occupation: Handlers-cleaners                      0.049331
# Occupation: Machine-op-inspct                      0.032228
# Occupation: Other-service                          0.155435
# Occupation: Priv-house-serv                        0.013232
# Occupation: Prof-specialty                         0.123912
# Occupation: Protective-serv                        0.006421
# Occupation: Sales                                  0.002757
# Occupation: Tech-support                           0.005202
# Relationship: Husband                              0.502899
# ...
# Native-country: England                                            0.000678
# Native-country: France                                             0.000662
# Native-country: Germany                                            0.000919
# Native-country: Greece                                             0.000144
# Native-country: Guatemala                                          0.002610
# Native-country: Haiti                                              0.000945
# Native-country: Holand-Netherlands                                 0.000385
# Native-country: Honduras                                           0.000399
# Native-country: Hong                                               0.000208
# Native-country: Hungary                                            0.000215
# Native-country: India                                              0.001651
# Native-country: Iran                                               0.000896
# Native-country: Ireland                                            0.000180
# Native-country: Italy                                              0.000579
# Native-country: Jamaica                                            0.001219
# Native-country: Japan                                              0.000843
# Native-country: Laos                                               0.000368
# Native-country: Mexico                                             0.028613
# Native-country: Nicaragua                                          0.001080
# Native-country: Outlying-US(Guam-USVI-etc)                         0.000723
# Native-country: Peru                                               0.000916
# Native-country: Philippines                                        0.000781
# Native-country: Poland                                             0.000211
# Native-country: Portugal                                           0.000580
# Native-country: Puerto-Rico                                        0.002160
# Native-country: Scotland                                           0.000258
# Native-country: South                                              0.000231
# Native-country: Taiwan                                             0.001103
# Native-country: Thailand                                           0.000242
# Native-country: Trinadad&Tobago                                    0.000398
# Native-country: United-States                                      0.009160
# Native-country: Vietnam                                            0.001862
#
#                                             Native-country: United-States  \
# Workclass: Federal-gov                                           0.011019
# Workclass: Local-gov                                             0.006819
# Workclass: Private                                               0.050878
# Workclass: Self-emp-inc                                          0.033167
# Workclass: Self-emp-not-inc                                      0.006199
# Workclass: State-gov                                             0.006112
# Education: 10th                                                  0.014109
# Education: 11th                                                  0.019482
# Education: 12th                                                  0.009729
# Education: 1st-4th                                               0.009192
# Education: 5th-6th                                               0.009802
# Education: 7th-8th                                               0.011564
# Education: 9th                                                   0.010851
# Education: Assoc-acdm                                            0.006446
# Education: Assoc-voc                                             0.006001
# Education: Bachelors                                             0.095483
# Education: Doctorate                                             0.018549
# Education: HS-grad                                               0.075633
# Education: Masters                                               0.058833
# Education: Preschool                                             0.009148
# Education: Prof-school                                           0.028288
# Marital-status: Divorced                                         0.064638
# Marital-status: Married-AF-spouse                                0.009116
# Marital-status: Married-civ-spouse                               0.514782
# Marital-status: Married-spouse-absent                            0.009563
# Marital-status: Never-married                                    0.348728
# Marital-status: Separated                                        0.015931
# Occupation: Adm-clerical                                         0.037324
# Occupation: Armed-Forces                                         0.009187
# Occupation: Craft-repair                                         0.005204
# Occupation: Exec-managerial                                      0.119326
# Occupation: Farming-fishing                                      0.012116
# Occupation: Handlers-cleaners                                    0.024787
# Occupation: Adm-clerical                                   0.058067
# Occupation: Armed-Forces                                   0.002026
# Occupation: Craft-repair                                   0.002520
# Occupation: Exec-managerial                                0.168008
# Occupation: Farming-fishing                                0.019281
# Occupation: Handlers-cleaners                              0.056803
# Occupation: Machine-op-inspct                              0.034596
# Occupation: Other-service                                  0.168835
# Occupation: Priv-house-serv                                0.008528
# Occupation: Prof-specialty                                 0.129364
# Occupation: Protective-serv                                0.003296
# Occupation: Sales                                          0.001782
# Occupation: Tech-support                                   0.002579
# Relationship: Husband                                      0.512438
# Relationship: Not-in-family                                0.195787
# Relationship: Other-relative                               0.047234
# Relationship: Own-child                                    0.290937
# Relationship: Unmarried                                    0.129354
# Race: Amer-Indian-Eskimo                                   0.005010
# Race: Asian-Pac-Islander                                   0.000754
# Race: Black                                                0.046182
# Race: Other                                                0.005957
# Sex: Female                                                0.231388
# Native-country: Cambodia                                   0.001688
# Native-country: Canada                                     0.001166
# Native-country: China                                      0.001008
# Native-country: Columbia                                   0.002782
# Native-country: Cuba                                       0.000817
# Native-country: Dominican-Republic                         0.003285
# Native-country: Ecuador                                    0.001656
# Native-country: El-Salvador                                0.002758
# Native-country: England                                    0.001251
# Native-country: France                                     0.001676
# Native-country: Germany                                    0.001311
# Native-country: Greece                                     0.001436
# Native-country: Guatemala                                  0.002789
# Native-country: Haiti                                      0.001849
# Native-country: Holand-Netherlands                         0.002268
# Native-country: Honduras                                   0.001996
# Native-country: Hong                                       0.001641
# Native-country: Hungary                                    0.001829
# Native-country: India                                      0.001948
# Native-country: Iran                                       0.001650
# Native-country: Ireland                                    0.001587
# Native-country: Italy                                      0.001269
# Native-country: Jamaica                                    0.001782
# Native-country: Japan                                      0.001499
# Native-country: Laos                                       0.001864
# Native-country: Mexico                                     0.026856
# Native-country: Nicaragua                                  0.002027
# Native-country: Outlying-US(Guam-USVI-etc)                 0.002129
# Native-country: Peru                                       0.001968
# Native-country: Philippines                                0.001098
# Native-country: Poland                                     0.001200
# Native-country: Portugal                                   0.001710
# Native-country: Puerto-Rico                                0.002397
# Native-country: Scotland                                   0.001919
# Native-country: South                                      0.001094
# Native-country: Taiwan                                     0.001777
# Native-country: Thailand                                   0.001775
# Native-country: Trinadad&Tobago                            0.001862
# Native-country: United-States                              0.009069
# Native-country: Vietnam                                    0.002298
#
# [90 rows x 90 columns]

# %% [markdown]
# The matrix being quite unwieldy can be studied better using a heatmap:

# %%
fig,ax = plt.subplots(1)
ax = sns.heatmap(rel_polarity_matrix, xticklabels=1, yticklabels=1,ax=ax)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1160.2166666666667">

# %% [markdown]
# By zooming in, we can identify (for example) that certain categories of the Marital-status variable exhibiting strong polarity with other variables (their categories). Perhaps as a variable itself, its univariate-polarity is high. Let us also explore a subset of the the data above as a graph:

# %%
# plot polarity graph, using the thresh variable as a cut-off for strong polarity
thresh = 0.6
polarity_graph_vals = rel_polarity_matrix[rel_polarity_matrix > thresh].fillna(0)
polarity_graph_vals = polarity_graph_vals.round(3)

# remove diagonal entries, and remove variables with weak polarity
cols = polarity_graph_vals.columns
for c in cols: polarity_graph_vals[c][c] = 0
var_mask = (polarity_graph_vals.T != 0).any()
polarity_graph_vals = polarity_graph_vals[var_mask]
polarity_graph_vals = polarity_graph_vals.T[var_mask].T

polarity_graph_vals

corr_graph = nx.from_pandas_adjacency(polarity_graph_vals)

pos = nx.spring_layout(corr_graph)

fig, ax = plt.subplots(1)


nx.draw_networkx(corr_graph,pos,ax=ax)
weights = nx.get_edge_attributes(corr_graph, 'weight')
nx.draw_networkx_edge_labels(corr_graph,pos,edge_labels=weights)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1161.3333333333333">

# %% [markdown]
# These are quite high polarity values, and the decision to use 0.6 as the cut-off for the plot above was arbitrary.
# It appears that the polarity is quite strong between particular categories of native-country and Marital-status.
#
# Other than the two plots above, we can also look at mosaic plots of every pair of variables (or bi-mekko plots, or qualitative mekko plots):

# %%
create_qualitative_mekko_charts(x_qual=df_qual.drop(columns=['Salary']),y_var=y_variable,share_y='row')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1162.45">

# %% [markdown]
# The plot above is the mosaic plot for each variable pairing, with the tiles having colors equal to the class (<= 50k or > 50k) they most represent - have a higher rel. freq for. The  *alpha* value of these colors are determined by such the corresponding rel. frequency. The color code is at the top of the plot, with 0 = > 50k, and 1 <= 50k.
#
# Due to the size of the diagram, the x-labels (and ticks) are shared for each column. Since the width of the tiles are consistent throughout a column this isn't a problem. However, the y-labels and ticks are also shared for each row which is a problem since the height of the tiles are not consistent within every column of each row. This formatting was neccessary for readability.
#
# What we can pull-out (by full-screening and zooming in) is for example that a married-civic-spouse (Relationship) who is either an exec, or in a prof-speciality (Occupation) is mostly earning > 50k. Likewise, for those who are wives or husbands or in an own-child (Relationship), and hold a masters, doctorate or attended a prof-school (Education).
#
# We can study if the polarity graph above corresponded to the values above:

# %%
create_qualitative_mekko_charts(x_qual=df_qual[['Native-country','Marital-status']],y_var=y_variable,share_y=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1160.2166666666667">

# %% [markdown]
# By studying the lower-left subplot, it would appear that the polarity values do not coincide actually coincide strongly with the purple tiles above, suggesting either that polarity is not useful measure for qualitative variables or that it provides usefulness somewhat orthoganal to these plots.

# %% [markdown]
# ## Exploring quantitative-qualitative relationships

# %% [markdown]
# We attempt class-seperation by plotting relationships between the quantitative (numerical) and the qualitative (categorical) variables. One manner of doing so is via stripplots:

# %% [markdown]
# ### Stripplots (quantitative mekko charts)

# %%
create_quantitative_mekko_charts(df_quant.copy(), df_qual.drop(columns=['Salary']).copy(), y_variable,
                                 num_samples=3000,hide_legend=True)
# Out:
# <img src="data:image/png;base64,..." width="1162.45">

# %% [markdown]
# The blue plots above represent the (> 50k) class whilst the orange is for the (<= 50k) class. We see again that Capital-gain has a good seperation between the two classes (even though we are only partially sampling the dataset). Capital-loss also appears to have some level of seperation. Note that within the Education variable, the categories: Doctorate and Prof-School appear to be mostly >50k, although this could be due to sampling error. This can be checked simply by a relative frequency vector for the categories of each variable. Lastly, we find that a strong proportion of Doctorate holders and those that attended Prof-School earned >50k.

# %% [markdown]
# ## Summary

# %% [markdown]
# All in all, we have found some potential variables for classification: Capital-gain, Capital-loss, Education, Relationship and Occupation. In the confirmatory analysis notebook, we will attempt both machine learning techniques for classification via decision trees, as well as a manual approach based on these variables identified.
